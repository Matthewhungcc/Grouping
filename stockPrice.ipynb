# %%
from tslearn.clustering import silhouette_score
from sklearn.decomposition import PCA
from sklearn import preprocessing
import numpy as np
import matplotlib as plt
from tslearn.clustering import TimeSeriesKMeans
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import math
from tslearn.clustering import TimeSeriesKMeans
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, \
    TimeSeriesResampler

# %%
windows = 300

all_asset_array = []
all_asset_class = []
all_asset_name = []
class_name = 0

for k in range(8):
    df = pd.read_excel('data.xlsx', sheet_name=k)
    num_of_asset = len(df.columns)
    for i in range(1, num_of_asset):
        asset_array = df.iloc[:,i].to_numpy()

        mask = ~np.isnan(asset_array)
        asset_array_no_na = asset_array[mask]

        class_name += 1
        try:
            asset_array_no_na = preprocessing.normalize([asset_array_no_na])[0]
        except Exception as ex:
            print(ex)
        for j in range(len(asset_array_no_na)-windows+1):
            all_asset_array.append([[i] for i in asset_array_no_na[j:j+windows]])
            all_asset_class.append(str(df.columns[i]))
            name = str(df.columns[i])+str(df.iloc[j,0])
            all_asset_name.append(name)
all_asset_array = np.array(all_asset_array)
print(all_asset_array.shape)
seed = 0 
np.random.seed(seed)
all_asset_array = TimeSeriesScalerMeanVariance().fit_transform(all_asset_array)
print(all_asset_array.shape[1])
# Out:
# Found array with 0 feature(s) (shape=(1, 0)) while a minimum of 1 is required by the normalize function.
# (37295, 300, 1)

# %%
# Author: Romain Tavenard
# License: BSD 3 clause

import numpy
import matplotlib.pyplot as plt

from tslearn.clustering import TimeSeriesKMeans
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, \
    TimeSeriesResampler

n_cluster = 10
seed = 0
numpy.random.seed(seed)
X_train = all_asset_array
numpy.random.shuffle(X_train)
# Keep only 50 time series
X_train = TimeSeriesScalerMeanVariance().fit_transform(X_train[:1000])
# Make time series shorter
#X_train = TimeSeriesResampler(sz=40).fit_transform(X_train)
sz = X_train.shape[1]

# Euclidean k-means
print("Euclidean k-means")
km = TimeSeriesKMeans(n_clusters=n_cluster, verbose=True, random_state=seed)
y_pred = km.fit_predict(X_train)

plt.figure(figsize=(26, 9))
for yi in range(n_cluster):
    plt.subplot(3, n_cluster, yi + 1)
    for xx in X_train[y_pred == yi]:
        plt.plot(xx.ravel(), "k-", alpha=.2)
    plt.plot(km.cluster_centers_[yi].ravel(), "r-")
    plt.xlim(0, sz)
    plt.ylim(-3, 3)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)
    if yi == 1:
        plt.title("Euclidean $k$-means")

# DBA-k-means
print("DBA k-means")
dba_km = TimeSeriesKMeans(n_clusters=n_cluster,
                          n_init=2,
                          metric="dtw",
                          verbose=True,
                          max_iter_barycenter=10,
                          random_state=seed)
y_pred = dba_km.fit_predict(X_train)

for yi in range(n_cluster):
    plt.subplot(3, n_cluster, n_cluster + 1 + yi)
    for xx in X_train[y_pred == yi]:
        plt.plot(xx.ravel(), "k-", alpha=.2)
    plt.plot(dba_km.cluster_centers_[yi].ravel(), "r-")
    plt.xlim(0, sz)
    plt.ylim(-3, 3)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)
    if yi == 1:
        plt.title("DBA $k$-means")

# Soft-DTW-k-means
print("Soft-DTW k-means")
sdtw_km = TimeSeriesKMeans(n_clusters=n_cluster,
                           metric="softdtw",
                           metric_params={"gamma": .01},
                           verbose=True,
                           random_state=seed)
y_pred = sdtw_km.fit_predict(X_train)

for yi in range(n_cluster):
    plt.subplot(3, n_cluster, n_cluster * 2 + 1 + yi)
    for xx in X_train[y_pred == yi]:
        plt.plot(xx.ravel(), "k-", alpha=.2)
    plt.plot(sdtw_km.cluster_centers_[yi].ravel(), "r-")
    plt.xlim(0, sz)
    plt.ylim(-3, 3)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)
    if yi == 1:
        plt.title("Soft-DTW $k$-means")
# Out:
# Euclidean k-means
# 536.470 --> 293.125 --> 292.496 --> 292.196 --> 292.052 --> 291.965 --> 291.871 --> 291.819 --> 291.756 --> 291.718 --> 291.683 --> 291.663 --> 291.646 --> 291.646 -->
# DBA k-means
# Init 1
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 4000 out of 4000 | elapsed:    2.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 4000 out of 4000 | elapsed:    2.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 4000 out of 4000 | elapsed:    2.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 4000 out of 4000 | elapsed:    2.4s finished
# ...

# %%
all_asset_array = []
all_asset_class = []
all_asset_name = []
class_name = 0

for k in range(1):
    df = pd.read_excel('PCA.xlsx', sheet_name=1)
    num_of_asset = len(df.columns)
    for i in range(1, num_of_asset):
        asset_array = df.iloc[:,i].to_numpy()
        asset_array = numpy.flip(asset_array)
        mask = ~np.isnan(asset_array)
        asset_array_no_na = asset_array[mask]

        class_name += 1
        if not len(asset_array_no_na) == 0:
            all_asset_array.append(asset_array_no_na)
seed = 0 
np.random.seed(seed)

# %%
n_cluster = 8
seed = 0
numpy.random.seed(seed)
X_train = all_asset_array
numpy.random.shuffle(X_train)
# Keep only 50 time series
X_train = TimeSeriesResampler(sz=500).fit_transform(X_train)
print(X_train.shape)
X_train = TimeSeriesScalerMeanVariance().fit_transform(X_train)
# Make time series shorter
sz = X_train.shape[1]

# Euclidean k-means
print("Euclidean k-means")
km = TimeSeriesKMeans(n_clusters=n_cluster, verbose=True, random_state=seed)
euclidean_y_pred = km.fit_predict(X_train)

plt.figure(figsize=(26, 9))
for yi in range(n_cluster):
    plt.subplot(3, n_cluster, yi + 1)
    for xx in X_train[euclidean_y_pred == yi]:
        plt.plot(xx.ravel(), "k-", alpha=.2)
    plt.plot(km.cluster_centers_[yi].ravel(), "r-")
    plt.xlim(0, sz)
    plt.ylim(-3, 3)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)
    if yi == 1:
        plt.title("Euclidean $k$-means")

# DBA-k-means
print("DBA k-means")
dba_km = TimeSeriesKMeans(n_clusters=n_cluster,
                          n_init=2,
                          metric="dtw",
                          verbose=True,
                          max_iter_barycenter=10,
                          random_state=seed)
DBA_y_pred = dba_km.fit_predict(X_train)

for yi in range(n_cluster):
    plt.subplot(3, n_cluster, n_cluster + 1 + yi)
    for xx in X_train[DBA_y_pred == yi]:
        plt.plot(xx.ravel(), "k-", alpha=.2)
    plt.plot(dba_km.cluster_centers_[yi].ravel(), "r-")
    plt.xlim(0, sz)
    plt.ylim(-3, 3)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)
    if yi == 1:
        plt.title("DBA $k$-means")

# Soft-DTW-k-means
print("Soft-DTW k-means")
# sdtw_km = TimeSeriesKMeans(n_clusters=n_cluster,
#                            metric="softdtw",
#                            metric_params={"gamma": .01},
#                            verbose=True,
#                            random_state=seed)
# sdwt_y_pred = sdtw_km.fit_predict(X_train)

# for yi in range(n_cluster):
#     plt.subplot(3, n_cluster, n_cluster * 2 + 1 + yi)
#     for xx in X_train[sdwt_y_pred == yi]:
#         plt.plot(xx.ravel(), "k-", alpha=.2)
#     plt.plot(sdtw_km.cluster_centers_[yi].ravel(), "r-")
#     plt.xlim(0, sz)
#     plt.ylim(-3, 3)
#     plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
#              transform=plt.gca().transAxes)
#     if yi == 1:
#         plt.title("Soft-DTW $k$-means")
# Out:
# (47, 500, 1)
# Euclidean k-means
# 162.746 --> 101.942 --> 101.942 -->
# DBA k-means
# Init 1
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 188 out of 188 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 188 out of 188 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 188 out of 188 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 188 out of 188 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
class_name = 0
length = 100

all_asset_array = []
all_asset_class = []
all_asset_name = []



df = pd.read_excel('PCA.xlsx', sheet_name=1)
num_of_asset = len(df.columns)
for i in range(1, num_of_asset):
    asset_array = df.iloc[:,i].to_numpy()
    mask = ~np.isnan(asset_array)
    asset_array_no_na = asset_array[mask]
    cstart = 0
    cend = length
    for j in range(int(math.ceil(len(asset_array_no_na)/length))):
        if i == 1 and j == 0:
            all_asset_array = [[] for k in range(math.ceil(len(asset_array_no_na)/length))]
            all_asset_class = [[] for k in range(math.ceil(len(asset_array_no_na)/length))]
        if cend >= len(asset_array_no_na):
            cend = len(asset_array_no_na)
        all_asset_array[j].append(asset_array_no_na[cstart:cend])
        cstart += length
        cend += length

# %%
for i in range(len(all_asset_array)):
    n_cluster = 8
    seed = 0
    numpy.random.seed(seed)
    X_train = all_asset_array[i]
    numpy.random.shuffle(X_train)
    # Keep only 50 time series
    X_train = TimeSeriesResampler(sz=200).fit_transform(X_train)
    print(X_train.shape)
    X_train = TimeSeriesScalerMeanVariance().fit_transform(X_train)
    # Make time series shorter
    sz = X_train.shape[1]

    # Euclidean k-means
    print("Euclidean k-means")
    km = TimeSeriesKMeans(n_clusters=n_cluster, verbose=True, random_state=seed)
    euclidean_y_pred = km.fit_predict(X_train)

    plt.figure(figsize=(26, 9))
    for yi in range(n_cluster):
        plt.subplot(3, n_cluster, yi + 1)
        for xx in X_train[euclidean_y_pred == yi]:
            plt.plot(xx.ravel(), "k-", alpha=.2)
        plt.plot(km.cluster_centers_[yi].ravel(), "r-")
        plt.xlim(0, sz)
        plt.ylim(-3, 3)
        plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
                transform=plt.gca().transAxes)
        if yi == 1:
            plt.title("Euclidean $k$-means")

    # DBA-k-means
    print("DBA k-means")
    dba_km = TimeSeriesKMeans(n_clusters=n_cluster,
                            n_init=2,
                            metric="dtw",
                            verbose=True,
                            max_iter_barycenter=10,
                            random_state=seed)
    DBA_y_pred = dba_km.fit_predict(X_train)

    for yi in range(n_cluster):
        plt.subplot(3, n_cluster, n_cluster + 1 + yi)
        for xx in X_train[DBA_y_pred == yi]:
            plt.plot(xx.ravel(), "k-", alpha=.2)
        plt.plot(dba_km.cluster_centers_[yi].ravel(), "r-")
        plt.xlim(0, sz)
        plt.ylim(-3, 3)
        plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
                transform=plt.gca().transAxes)
        if yi == 1:
            plt.title("DBA $k$-means")
    plt.show()

    # Soft-DTW-k-means
    print("Soft-DTW k-means")
    # sdtw_km = TimeSeriesKMeans(n_clusters=n_cluster,
    #                            metric="softdtw",
    #                            metric_params={"gamma": .01},
    #                            verbose=True,
    #                            random_state=seed)
    # sdwt_y_pred = sdtw_km.fit_predict(X_train)

    # for yi in range(n_cluster):
    #     plt.subplot(3, n_cluster, n_cluster * 2 + 1 + yi)
    #     for xx in X_train[sdwt_y_pred == yi]:
    #         plt.plot(xx.ravel(), "k-", alpha=.2)
    #     plt.plot(sdtw_km.cluster_centers_[yi].ravel(), "r-")
    #     plt.xlim(0, sz)
    #     plt.ylim(-3, 3)
    #     plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
    #              transform=plt.gca().transAxes)
    #     if yi == 1:
    #         plt.title("Soft-DTW $k$-means")
# Out:
# (47, 200, 1)
# Euclidean k-means
# 41.673 --> 26.062 --> 25.533 --> 25.533 -->
# DBA k-means
# Init 1
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 188 out of 188 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 188 out of 188 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 188 out of 188 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 188 out of 188 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...
