# %%
import math
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import plotly.graph_objects as go

df = pd.read_excel('Data.xlsx', sheet_name=5)
ordered_df = df.iloc[::-1]

date_list = df.iloc[:, 0].values
price_list = df.iloc[:, 1].values
features_list = df.iloc[:, [1, 2, 3, 4]].values

#Scale data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(features_list)
price_list = np.reshape(price_list, (price_list.shape[0], 1))
output_scaler = StandardScaler()
scaled_output_data = output_scaler.fit_transform(price_list)
print(scaled_output_data, scaled_data)
#Train test split
training_data_len = math.ceil(len(scaled_data)* .8)
training_data_len

#Train test split
train_data = scaled_data[0:training_data_len, :]
x_train = []
y_train = []
look_back_window = 14

for i in range(look_back_window, len(train_data)):
    x_train.append(train_data[i-look_back_window:i])
    y_train.append(train_data[i, 0])
#Convert to np array
x_train, y_train = np.array(x_train), np.array(y_train)

test_data = scaled_data[training_data_len-look_back_window:, :]

x_test = []
y_test = price_list[training_data_len:]
y_test = np.array(y_test)
y_test = np.reshape(y_test, (y_test.shape[0], 1))

for i in range(look_back_window, len(test_data)):
    x_test.append(test_data[i-look_back_window:i])

x_test = np.array(x_test)
# Out:
# [[-0.48283747]
#  [-0.4597184 ]
#  [-0.48294487]
#  ...
#  [ 2.48179327]
#  [ 2.46814442]
#  [ 2.37603912]] [[-0.48283747  0.60379185 -0.46732082 -0.52125274]
#  [-0.4597184   0.44544826 -0.47214525 -0.47219471]
#  [-0.48294487 -0.04637153 -0.47917926 -0.46081404]
#  ...
#  [ 2.48179327 -0.57861472  2.53947557  2.55417938]
#  [ 2.46814442 -0.91214917  2.47497296  2.52382099]
#  [ 2.37603912 -0.8345886   2.43923359  2.41590326]]

# %%
from tensorflow import keras
from tensorflow.keras import layers
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

# %%
input_shape = x_train.shape[1:]

head_size_list = [64, 128, 256, 512]
ff_dim_list = [1, 2, 4, 8, 16]
mlp_units_list = [64, 128, 256, 512]
mlp_dropout_list = [0.1, 0.2, 0.3, 0.4]
dropout_list = [0.1, 0.2, 0.3, 0.4]
result = []
for head_size in head_size_list:
    for ff_dim in ff_dim_list:
        for mlp_units in mlp_units_list:
            for mlp_dropout in mlp_dropout_list:
                for dropout in dropout_list:
                    model = build_model(
                        input_shape,
                        head_size=head_size,
                        num_heads=4,
                        ff_dim=ff_dim,
                        num_transformer_blocks=10,
                        mlp_units=[mlp_units],
                        mlp_dropout=mlp_dropout,
                        dropout=dropout,
                    )

                    model.compile(optimizer='adam', loss="mean_squared_error")

                    callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

                    model.fit(
                        x_train,
                        y_train,
                        validation_split=0.2,
                        epochs=200,
                        batch_size=64,
                        callbacks=callbacks,
                        verbose=0
                    )
                    predictions = model.predict(x_test)
                    predictions = output_scaler.inverse_transform(predictions)
                    rmse = np.sqrt(np.mean(predictions - y_test)**2)
                    print(head_size, ff_dim, mlp_units, mlp_dropout, dropout)
                    print(rmse)
                    result.append({"rmse":rmse, "head_size":head_size, "ff_dim":ff_dim, "mlp_units":mlp_units, "mlp_dropout":mlp_dropout, "dropout":dropout})
                    if  rmse < 100:
                        train = np.squeeze(price_list[:training_data_len])
                        valid = np.squeeze(price_list[training_data_len:])
                        predictions = np.squeeze(predictions)
                        train_date_list = date_list[:training_data_len]
                        valid_date_list = date_list[training_data_len:]
                        valid_date_list2 = date_list[training_data_len:]
                        fig = go.Figure()
                        fig.add_trace(go.Scatter(x=train_date_list, y=train, name='train',  mode='lines'))
                        fig.add_trace(go.Scatter(x=valid_date_list, y=valid, name='valid',  mode='lines'))
                        fig.add_trace(go.Scatter(x=valid_date_list2, y=predictions, name='predict',  mode='lines'))
                        fig.show()
# Out:
# 8/8 [==============================] - 1s 27ms/step
# 64 1 64 0.1 0.1
# 2355.6368763497208
# 8/8 [==============================] - 1s 24ms/step
# 64 1 64 0.1 0.2
# 634.0488318962779
# 8/8 [==============================] - 1s 27ms/step
# 64 1 64 0.1 0.3
# 1921.9875372165588
# 8/8 [==============================] - 1s 29ms/step
# 64 1 64 0.1 0.4
# 1923.1459616560278
# 8/8 [==============================] - 1s 27ms/step
# 64 1 64 0.2 0.1
# 1907.3365158949443
# 8/8 [==============================] - 1s 26ms/step
# 64 1 64 0.2 0.2
# 1946.7698674892024
# 8/8 [==============================] - 2s 24ms/step
# 64 1 64 0.2 0.3
# 151.80522619728148
# 8/8 [==============================] - 1s 28ms/step
# 64 1 64 0.2 0.4
# 2380.936131472704
# 8/8 [==============================] - 1s 28ms/step
# 64 1 64 0.3 0.1
# 78.49964748475608
# 8/8 [==============================] - 1s 27ms/step
# 64 1 64 0.3 0.2
# 2060.3232449663365
# 8/8 [==============================] - 2s 28ms/step
# 64 1 64 0.3 0.3
# 2016.8379256581875
# 8/8 [==============================] - 1s 28ms/step
# 64 1 64 0.3 0.4
# 137.61263100228658
# 8/8 [==============================] - 2s 29ms/step
# 64 1 64 0.4 0.1
# 529.5040479706554
# 8/8 [==============================] - 1s 28ms/step
# 64 1 64 0.4 0.2
# 23.331681116615865
# 8/8 [==============================] - 1s 28ms/step
# 64 1 64 0.4 0.3
# 2099.541113678227
# 8/8 [==============================] - 1s 29ms/step
# 64 1 64 0.4 0.4
# 129.40358807323423
# 8/8 [==============================] - 1s 24ms/step
# 64 1 128 0.1 0.1
# 2251.667653947535
# 8/8 [==============================] - 1s 29ms/step
# 64 1 128 0.1 0.2
# 272.6424260829522
# 8/8 [==============================] - 1s 36ms/step
# 64 1 128 0.1 0.3
# 201.0854063452744
# 8/8 [==============================] - 1s 30ms/step
# 64 1 128 0.1 0.4
# 415.11871764640495
# 8/8 [==============================] - 1s 26ms/step
# 64 1 128 0.2 0.1
# 605.9082128509273
# 8/8 [==============================] - 1s 27ms/step
# 64 1 128 0.2 0.2
# 313.227109136814
# 8/8 [==============================] - 1s 24ms/step
# 64 1 128 0.2 0.3
# 233.88587199885671
# 8/8 [==============================] - 2s 36ms/step
# 64 1 128 0.2 0.4
# 28.886196924225104
# 8/8 [==============================] - 1s 29ms/step
# 64 1 128 0.3 0.1
# 2420.311676571234
# 8/8 [==============================] - 2s 39ms/step
# 64 1 128 0.3 0.2
# 117.41845981008636
# 8/8 [==============================] - 2s 31ms/step
# 64 1 128 0.3 0.3
# 356.3040491615854
# 8/8 [==============================] - 1s 27ms/step
# 64 1 128 0.3 0.4
# 2066.781215562278
# 8/8 [==============================] - 1s 25ms/step
# 64 1 128 0.4 0.1
# 1911.242677567645
# 8/8 [==============================] - 1s 28ms/step
# 64 1 128 0.4 0.2
# 331.0880422700711
# 8/8 [==============================] - 1s 29ms/step
# 64 1 128 0.4 0.3
# 395.660748539126
# 8/8 [==============================] - 1s 27ms/step
# 64 1 128 0.4 0.4
# 2320.0322710238825
# 8/8 [==============================] - 1s 29ms/step
# 64 1 256 0.1 0.1
# 477.70519205729164
# 8/8 [==============================] - 2s 26ms/step
# 64 1 256 0.1 0.2
# 694.8380690659933
# 8/8 [==============================] - 1s 26ms/step
# 64 1 256 0.1 0.3
# 502.61207920477636
# 8/8 [==============================] - 1s 27ms/step
# 64 1 256 0.1 0.4
# 426.92772822186225
# 8/8 [==============================] - 1s 27ms/step
# 64 1 256 0.2 0.1
# 1695.8545500468435
# 8/8 [==============================] - 1s 26ms/step
# 64 1 256 0.2 0.2
# 134.2836366234756
# 8/8 [==============================] - 1s 27ms/step
# 64 1 256 0.2 0.3
# 529.6060789030741
# 8/8 [==============================] - 1s 27ms/step
# 64 1 256 0.2 0.4
# 1937.9755926861028
# 8/8 [==============================] - 2s 27ms/step
# 64 1 256 0.3 0.1
# 2204.7360113376526
# 8/8 [==============================] - 1s 26ms/step
# 64 1 256 0.3 0.2
# 349.7062688563897
# 8/8 [==============================] - 1s 31ms/step
# 64 1 256 0.3 0.3
# 307.64026256034043
# 8/8 [==============================] - 1s 29ms/step
# 64 1 256 0.3 0.4
# 381.2690784981581
# 8/8 [==============================] - 1s 28ms/step
# 64 1 256 0.4 0.1
# 2147.880736113758
# 8/8 [==============================] - 1s 28ms/step
# 64 1 256 0.4 0.2
# 2130.252648131828
# 8/8 [==============================] - 1s 30ms/step
# 64 1 256 0.4 0.3
# 355.072116560277
# 8/8 [==============================] - 1s 26ms/step
# 64 1 256 0.4 0.4
# 28.58554429465193
# 8/8 [==============================] - 1s 27ms/step
# 64 1 512 0.1 0.1
# 361.1847745569741
# 8/8 [==============================] - 1s 30ms/step
# 64 1 512 0.1 0.2
# 1453.8715158353975
# 8/8 [==============================] - 1s 27ms/step
# 64 1 512 0.1 0.3
# 2200.3780555290905
# 8/8 [==============================] - 1s 27ms/step
# 64 1 512 0.1 0.4
# 1780.339402907457
# 8/8 [==============================] - 1s 28ms/step
# 64 1 512 0.2 0.1
# 250.36747610200712
# 8/8 [==============================] - 1s 27ms/step
# 64 1 512 0.2 0.2
# 1959.1366262544464
# 8/8 [==============================] - 1s 27ms/step
# 64 1 512 0.2 0.3
# 132.42879708142783
# 8/8 [==============================] - 1s 27ms/step
# 64 1 512 0.2 0.4
# 594.683515148628
# 8/8 [==============================] - 1s 27ms/step
# 64 1 512 0.3 0.1
# 421.14066648405736
# 8/8 [==============================] - 1s 29ms/step
# 64 1 512 0.3 0.2
# 1556.7467500516073
# 8/8 [==============================] - 1s 27ms/step
# 64 1 512 0.3 0.3
# 269.3250512099848
# 8/8 [==============================] - 1s 26ms/step
# 64 1 512 0.3 0.4
# 1889.6215694272423
# 8/8 [==============================] - 1s 27ms/step
# 64 1 512 0.4 0.1
# 255.23146992505082
# 8/8 [==============================] - 1s 30ms/step
# 64 1 512 0.4 0.2
# 1834.0564791547577
# 8/8 [==============================] - 1s 29ms/step
# 64 1 512 0.4 0.3
# 458.81812496030227
# 8/8 [==============================] - 1s 28ms/step
# 64 1 512 0.4 0.4
# 685.3559826362423
# 8/8 [==============================] - 1s 28ms/step
# 64 2 64 0.1 0.1
# 2237.312598053227
# 8/8 [==============================] - 1s 27ms/step
# 64 2 64 0.1 0.2
# 475.10912569867884
# 8/8 [==============================] - 1s 27ms/step
# 64 2 64 0.1 0.3
# 1061.8102792135098
# 8/8 [==============================] - 1s 29ms/step
# 64 2 64 0.1 0.4
# 1672.9150631788302
# 8/8 [==============================] - 1s 29ms/step
# 64 2 64 0.2 0.1
# 542.0525039300685
# 8/8 [==============================] - 1s 30ms/step
# 64 2 64 0.2 0.2
# 1823.408419774994
# 8/8 [==============================] - 1s 31ms/step
# 64 2 64 0.2 0.3
# 2170.401510893039
# 8/8 [==============================] - 1s 27ms/step
# 64 2 64 0.2 0.4
# 1782.117556985995
# 8/8 [==============================] - 1s 27ms/step
# 64 2 64 0.3 0.1
# 1997.5172449623667
# 8/8 [==============================] - 1s 29ms/step
# 64 2 64 0.3 0.2
# 2139.8133657067774
# 8/8 [==============================] - 1s 28ms/step
# 64 2 64 0.3 0.3
# 330.789830451283
# 8/8 [==============================] - 1s 28ms/step
# 64 2 64 0.3 0.4
# 415.3292045779344
# 8/8 [==============================] - 1s 28ms/step
# 64 2 64 0.4 0.1
# 1928.7944934379766
# 8/8 [==============================] - 1s 28ms/step
# 64 2 64 0.4 0.2
# 53.865832023310475
# 8/8 [==============================] - 1s 29ms/step
# 64 2 64 0.4 0.3
# 2228.028258582635
# 8/8 [==============================] - 1s 31ms/step
# 64 2 64 0.4 0.4
# 121.98598652661329
# 8/8 [==============================] - 1s 29ms/step
# 64 2 128 0.1 0.1
# 694.1433301972179
# 8/8 [==============================] - 1s 29ms/step
# 64 2 128 0.1 0.2
# 466.17634575076215
# 8/8 [==============================] - 1s 28ms/step
# 64 2 128 0.1 0.3
# 21.12706646182674
# 8/8 [==============================] - 1s 28ms/step
# 64 2 128 0.1 0.4
# 580.0592664268927
# 8/8 [==============================] - 1s 32ms/step
# 64 2 128 0.2 0.1
# 1814.278303738726
# 8/8 [==============================] - 1s 34ms/step
# 64 2 128 0.2 0.2
# 425.54973303321896
# 8/8 [==============================] - 1s 32ms/step
# 64 2 128 0.2 0.3
# 91.07566056910568
# 8/8 [==============================] - 2s 36ms/step
# 64 2 128 0.2 0.4
# 508.58035084794204
# 8/8 [==============================] - 1s 30ms/step
# 64 2 128 0.3 0.1
# 486.78514612709597
# 8/8 [==============================] - 1s 29ms/step
# 64 2 128 0.3 0.2
# 2194.6897943264103
# 8/8 [==============================] - 2s 38ms/step
# 64 2 128 0.3 0.3
# 727.8630508050685
# 8/8 [==============================] - 1s 32ms/step
# 64 2 128 0.3 0.4
# 1745.7999191160127
# 8/8 [==============================] - 1s 31ms/step
# 64 2 128 0.4 0.1
# 1945.4165568033857
# 8/8 [==============================] - 1s 28ms/step
# 64 2 128 0.4 0.2
# 1707.9614360033984
# 8/8 [==============================] - 1s 29ms/step
# 64 2 128 0.4 0.3
# 2307.3662360462718
# 8/8 [==============================] - 1s 29ms/step
# 64 2 128 0.4 0.4
# 126.94695618172004
# 8/8 [==============================] - 1s 29ms/step
# 64 2 256 0.1 0.1
# 1988.9700915825078
# 8/8 [==============================] - 1s 30ms/step
# 64 2 256 0.1 0.2
# 940.7750182609248
# 8/8 [==============================] - 2s 34ms/step
# 64 2 256 0.1 0.3
# 1760.1636424987298
# 8/8 [==============================] - 1s 29ms/step
# 64 2 256 0.1 0.4
# 548.5387764783409
# 8/8 [==============================] - 1s 29ms/step
# 64 2 256 0.2 0.1
# 2366.771422893245
# 8/8 [==============================] - 1s 30ms/step
# 64 2 256 0.2 0.2
# 568.2731256748602
# 8/8 [==============================] - 1s 28ms/step
# 64 2 256 0.2 0.3
# 525.2344234311483
# 8/8 [==============================] - 1s 28ms/step
# 64 2 256 0.2 0.4
# 50.084973640752025
# 8/8 [==============================] - 1s 31ms/step
# 64 2 256 0.3 0.1
# 610.8366012449186
# 8/8 [==============================] - 1s 28ms/step
# 64 2 256 0.3 0.2
# 771.8200115917173
# 8/8 [==============================] - 1s 29ms/step
# 64 2 256 0.3 0.3
# 743.947063960874
# 8/8 [==============================] - 1s 28ms/step
# 64 2 256 0.3 0.4
# 340.6901833635036
# 8/8 [==============================] - 2s 29ms/step
# 64 2 256 0.4 0.1
# 165.37511095496694
# 8/8 [==============================] - 1s 28ms/step
# 64 2 256 0.4 0.2
# 1933.2425644293066
# 8/8 [==============================] - 1s 30ms/step
# 64 2 256 0.4 0.3
# 2408.907612423781
# 8/8 [==============================] - 1s 31ms/step
# 64 2 256 0.4 0.4
# 601.9883802956681
# 8/8 [==============================] - 1s 29ms/step
# 64 2 512 0.1 0.1
# 1991.4107004057103
# 8/8 [==============================] - 2s 35ms/step
# 64 2 512 0.1 0.2
# 577.488065691692
# 8/8 [==============================] - 1s 32ms/step
# 64 2 512 0.1 0.3
# 854.0761409108231
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 29
#      25 model.compile(optimizer='adam', loss="mean_squared_error")
#      27 callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
# ---> 29 model.fit(
#      30     x_train,
#      31     y_train,
#      32     validation_split=0.2,
#      33     epochs=200,
#      34     batch_size=64,
#      35     callbacks=callbacks,
#      36     verbose=0
#      37 )
#      38 predictions = model.predict(x_test)
#      39 predictions = output_scaler.inverse_transform(predictions)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
while True:
    model = build_model(
        input_shape,
        head_size=64,
        num_heads=4,
        ff_dim=1,
        num_transformer_blocks=10,
        mlp_units=[128],
        mlp_dropout=0.1,
        dropout=0.1,
    )

    model.compile(optimizer='adam', loss="mean_squared_error")

    callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

    model.fit(
        x_train,
        y_train,
        validation_split=0.2,
        epochs=200,
        batch_size=64,
        callbacks=callbacks,
    )
    predictions = model.predict(x_test)
    predictions = output_scaler.inverse_transform(predictions)
    rmse = np.sqrt(np.mean(predictions - y_test)**2)
    print(rmse)
    if  rmse < 100:
        break
# Out:
# Epoch 1/200
# 13/13 [==============================] - 13s 229ms/step - loss: 0.1114 - val_loss: 0.3203
# Epoch 2/200
# 13/13 [==============================] - 2s 118ms/step - loss: 0.0666 - val_loss: 0.1728
# Epoch 3/200
# 13/13 [==============================] - 2s 118ms/step - loss: 0.0380 - val_loss: 0.2061
# Epoch 4/200
# 13/13 [==============================] - 2s 118ms/step - loss: 0.0277 - val_loss: 0.1162
# Epoch 5/200
# 13/13 [==============================] - 2s 122ms/step - loss: 0.0179 - val_loss: 0.0584
# Epoch 6/200
# 13/13 [==============================] - 2s 118ms/step - loss: 0.0174 - val_loss: 0.0446
# Epoch 7/200
# 13/13 [==============================] - 2s 128ms/step - loss: 0.0179 - val_loss: 0.0655
# Epoch 8/200
# 13/13 [==============================] - 1s 111ms/step - loss: 0.0162 - val_loss: 0.0375
# Epoch 9/200
# 13/13 [==============================] - 1s 111ms/step - loss: 0.0243 - val_loss: 0.0416
# Epoch 10/200
# 13/13 [==============================] - 2s 120ms/step - loss: 0.0182 - val_loss: 0.0204
# Epoch 11/200
# 13/13 [==============================] - 1s 115ms/step - loss: 0.0159 - val_loss: 0.0333
# Epoch 12/200
# 13/13 [==============================] - 1s 114ms/step - loss: 0.0164 - val_loss: 0.0547
# Epoch 13/200
# 13/13 [==============================] - 2s 116ms/step - loss: 0.0153 - val_loss: 0.0410
# Epoch 14/200
# 13/13 [==============================] - 1s 109ms/step - loss: 0.0128 - val_loss: 0.0451
# Epoch 15/200
# 13/13 [==============================] - 1s 113ms/step - loss: 0.0111 - val_loss: 0.0309
# Epoch 16/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.0112 - val_loss: 0.0245
# Epoch 17/200
# 13/13 [==============================] - 1s 114ms/step - loss: 0.0113 - val_loss: 0.0213
# Epoch 18/200
# 13/13 [==============================] - 1s 115ms/step - loss: 0.0114 - val_loss: 0.0258
# Epoch 19/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.0103 - val_loss: 0.0283
# Epoch 20/200
# 13/13 [==============================] - 1s 113ms/step - loss: 0.0114 - val_loss: 0.0295
# 8/8 [==============================] - 1s 22ms/step
# 607.9793331983612
# Epoch 1/200
# 13/13 [==============================] - 13s 211ms/step - loss: 0.1684 - val_loss: 0.7550
# Epoch 2/200
# 13/13 [==============================] - 2s 119ms/step - loss: 0.0992 - val_loss: 0.5580
# Epoch 3/200
# 13/13 [==============================] - 2s 116ms/step - loss: 0.0808 - val_loss: 0.4642
# Epoch 4/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0810 - val_loss: 0.5338
# Epoch 5/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.0693 - val_loss: 0.4679
# Epoch 6/200
# 13/13 [==============================] - 1s 111ms/step - loss: 0.0649 - val_loss: 0.5890
# Epoch 7/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.0649 - val_loss: 0.5341
# Epoch 8/200
# 13/13 [==============================] - 1s 111ms/step - loss: 0.0603 - val_loss: 0.3660
# Epoch 9/200
# 13/13 [==============================] - 1s 108ms/step - loss: 0.0509 - val_loss: 0.4344
# Epoch 10/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.0460 - val_loss: 0.4242
# Epoch 11/200
# 13/13 [==============================] - 2s 116ms/step - loss: 0.0426 - val_loss: 0.4151
# Epoch 12/200
# 13/13 [==============================] - 1s 115ms/step - loss: 0.0391 - val_loss: 0.4252
# Epoch 13/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0365 - val_loss: 0.4048
# Epoch 14/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.0328 - val_loss: 0.5295
# Epoch 15/200
# 13/13 [==============================] - 1s 113ms/step - loss: 0.0347 - val_loss: 0.3822
# Epoch 16/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0314 - val_loss: 0.4489
# Epoch 17/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0326 - val_loss: 0.6153
# Epoch 18/200
# 13/13 [==============================] - 1s 115ms/step - loss: 0.0281 - val_loss: 0.4094
# 8/8 [==============================] - 1s 31ms/step
# 2128.728663300305
# Epoch 1/200
# 13/13 [==============================] - 15s 220ms/step - loss: 0.1391 - val_loss: 0.3959
# Epoch 2/200
# 13/13 [==============================] - 2s 120ms/step - loss: 0.0804 - val_loss: 0.3668
# Epoch 3/200
# 13/13 [==============================] - 2s 120ms/step - loss: 0.0738 - val_loss: 0.4631
# Epoch 4/200
# 13/13 [==============================] - 2s 121ms/step - loss: 0.0613 - val_loss: 0.3789
# Epoch 5/200
# 13/13 [==============================] - 2s 122ms/step - loss: 0.0567 - val_loss: 0.2421
# Epoch 6/200
# 13/13 [==============================] - 2s 124ms/step - loss: 0.0562 - val_loss: 0.2990
# Epoch 7/200
# 13/13 [==============================] - 2s 124ms/step - loss: 0.0582 - val_loss: 0.2814
# Epoch 8/200
# 13/13 [==============================] - 2s 121ms/step - loss: 0.0524 - val_loss: 0.2364
# Epoch 9/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0501 - val_loss: 0.2386
# Epoch 10/200
# 13/13 [==============================] - 2s 116ms/step - loss: 0.0501 - val_loss: 0.2141
# Epoch 11/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0549 - val_loss: 0.3735
# Epoch 12/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.0506 - val_loss: 0.2938
# Epoch 13/200
# 13/13 [==============================] - 1s 111ms/step - loss: 0.0462 - val_loss: 0.2382
# Epoch 14/200
# 13/13 [==============================] - 1s 109ms/step - loss: 0.0430 - val_loss: 0.2380
# Epoch 15/200
# 13/13 [==============================] - 1s 116ms/step - loss: 0.0459 - val_loss: 0.2631
# Epoch 16/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0400 - val_loss: 0.2586
# Epoch 17/200
# 13/13 [==============================] - 1s 108ms/step - loss: 0.0403 - val_loss: 0.2368
# Epoch 18/200
# 13/13 [==============================] - 1s 113ms/step - loss: 0.0403 - val_loss: 0.2774
# Epoch 19/200
# 13/13 [==============================] - 1s 115ms/step - loss: 0.0376 - val_loss: 0.2205
# Epoch 20/200
# 13/13 [==============================] - 1s 115ms/step - loss: 0.0384 - val_loss: 0.2379
# 8/8 [==============================] - 1s 23ms/step
# 2008.6522547279917
# Epoch 1/200
# 13/13 [==============================] - 13s 222ms/step - loss: 0.2237 - val_loss: 0.3267
# Epoch 2/200
# 13/13 [==============================] - 2s 121ms/step - loss: 0.0543 - val_loss: 0.1411
# Epoch 3/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.0295 - val_loss: 0.0449
# Epoch 4/200
# 13/13 [==============================] - 2s 116ms/step - loss: 0.0253 - val_loss: 0.0362
# Epoch 5/200
# 13/13 [==============================] - 1s 109ms/step - loss: 0.0200 - val_loss: 0.0271
# Epoch 6/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.0193 - val_loss: 0.0295
# Epoch 7/200
# 13/13 [==============================] - 2s 125ms/step - loss: 0.0196 - val_loss: 0.0182
# Epoch 8/200
# 13/13 [==============================] - 1s 109ms/step - loss: 0.0177 - val_loss: 0.0633
# Epoch 9/200
# 13/13 [==============================] - 1s 102ms/step - loss: 0.0181 - val_loss: 0.0719
# Epoch 10/200
# 13/13 [==============================] - 1s 103ms/step - loss: 0.0150 - val_loss: 0.0383
# Epoch 11/200
# 13/13 [==============================] - 1s 105ms/step - loss: 0.0151 - val_loss: 0.0146
# Epoch 12/200
# 13/13 [==============================] - 1s 105ms/step - loss: 0.0146 - val_loss: 0.0251
# Epoch 13/200
# 13/13 [==============================] - 1s 104ms/step - loss: 0.0192 - val_loss: 0.0233
# Epoch 14/200
# 13/13 [==============================] - 1s 109ms/step - loss: 0.0170 - val_loss: 0.0135
# Epoch 15/200
# 13/13 [==============================] - 1s 104ms/step - loss: 0.0161 - val_loss: 0.0132
# Epoch 16/200
# 13/13 [==============================] - 1s 104ms/step - loss: 0.0170 - val_loss: 0.0162
# Epoch 17/200
# 13/13 [==============================] - 1s 102ms/step - loss: 0.0098 - val_loss: 0.0160
# Epoch 18/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0122 - val_loss: 0.0080
# Epoch 19/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0106 - val_loss: 0.0082
# Epoch 20/200
# 13/13 [==============================] - 1s 105ms/step - loss: 0.0116 - val_loss: 0.0088
# Epoch 21/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.0104 - val_loss: 0.0186
# Epoch 22/200
# 13/13 [==============================] - 1s 115ms/step - loss: 0.0096 - val_loss: 0.0130
# Epoch 23/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0105 - val_loss: 0.0191
# Epoch 24/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.0099 - val_loss: 0.0163
# Epoch 25/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.0124 - val_loss: 0.0256
# Epoch 26/200
# 13/13 [==============================] - 1s 111ms/step - loss: 0.0102 - val_loss: 0.0352
# Epoch 27/200
# 13/13 [==============================] - 1s 109ms/step - loss: 0.0096 - val_loss: 0.0079
# Epoch 28/200
# 13/13 [==============================] - 1s 105ms/step - loss: 0.0120 - val_loss: 0.0216
# Epoch 29/200
# 13/13 [==============================] - 1s 113ms/step - loss: 0.0096 - val_loss: 0.0083
# Epoch 30/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.0106 - val_loss: 0.0144
# Epoch 31/200
# 13/13 [==============================] - 1s 104ms/step - loss: 0.0101 - val_loss: 0.0084
# Epoch 32/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.0079 - val_loss: 0.0114
# Epoch 33/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.0080 - val_loss: 0.0127
# Epoch 34/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.0091 - val_loss: 0.0096
# Epoch 35/200
# 13/13 [==============================] - 1s 108ms/step - loss: 0.0072 - val_loss: 0.0066
# Epoch 36/200
# 13/13 [==============================] - 1s 105ms/step - loss: 0.0089 - val_loss: 0.0153
# Epoch 37/200
# 13/13 [==============================] - 1s 109ms/step - loss: 0.0078 - val_loss: 0.0092
# Epoch 38/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0079 - val_loss: 0.0514
# Epoch 39/200
# 13/13 [==============================] - 1s 108ms/step - loss: 0.0091 - val_loss: 0.0139
# Epoch 40/200
# 13/13 [==============================] - 2s 126ms/step - loss: 0.0095 - val_loss: 0.0352
# Epoch 41/200
# 13/13 [==============================] - 1s 115ms/step - loss: 0.0073 - val_loss: 0.0217
# Epoch 42/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.0075 - val_loss: 0.0076
# Epoch 43/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.0093 - val_loss: 0.0314
# Epoch 44/200
# 13/13 [==============================] - 1s 113ms/step - loss: 0.0081 - val_loss: 0.0408
# Epoch 45/200
# 13/13 [==============================] - 2s 126ms/step - loss: 0.0081 - val_loss: 0.0165
# 8/8 [==============================] - 1s 22ms/step
# 148.19702128588668
# Epoch 1/200
# 13/13 [==============================] - 16s 220ms/step - loss: 0.3475 - val_loss: 1.1746
# Epoch 2/200
# 13/13 [==============================] - 1s 112ms/step - loss: 0.1256 - val_loss: 0.9343
# Epoch 3/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0879 - val_loss: 0.4435
# Epoch 4/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0812 - val_loss: 0.4628
# Epoch 5/200
# 13/13 [==============================] - 1s 113ms/step - loss: 0.0724 - val_loss: 0.4371
# Epoch 6/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.0716 - val_loss: 0.6662
# Epoch 7/200
# 13/13 [==============================] - 1s 108ms/step - loss: 0.0680 - val_loss: 0.4456
# Epoch 8/200
# 13/13 [==============================] - 1s 113ms/step - loss: 0.0626 - val_loss: 0.3572
# Epoch 9/200
# 13/13 [==============================] - 1s 109ms/step - loss: 0.0610 - val_loss: 0.3751
# Epoch 10/200
# 13/13 [==============================] - 1s 109ms/step - loss: 0.0556 - val_loss: 0.4190
# Epoch 11/200
# 13/13 [==============================] - 1s 111ms/step - loss: 0.0595 - val_loss: 0.3784
# Epoch 12/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0656 - val_loss: 0.4116
# Epoch 13/200
# 13/13 [==============================] - 1s 116ms/step - loss: 0.0554 - val_loss: 0.2485
# Epoch 14/200
# 13/13 [==============================] - 1s 113ms/step - loss: 0.0512 - val_loss: 0.2750
# Epoch 15/200
# 13/13 [==============================] - 1s 105ms/step - loss: 0.0551 - val_loss: 0.3717
# Epoch 16/200
# 13/13 [==============================] - 1s 111ms/step - loss: 0.0512 - val_loss: 0.2697
# Epoch 17/200
# 13/13 [==============================] - 1s 111ms/step - loss: 0.0462 - val_loss: 0.2163
# Epoch 18/200
# 13/13 [==============================] - 1s 105ms/step - loss: 0.0446 - val_loss: 0.6636
# Epoch 19/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0521 - val_loss: 0.4373
# Epoch 20/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.0492 - val_loss: 0.3438
# Epoch 21/200
# 13/13 [==============================] - 1s 111ms/step - loss: 0.0443 - val_loss: 0.1672
# Epoch 22/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.0466 - val_loss: 0.3433
# Epoch 23/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0402 - val_loss: 0.2194
# Epoch 24/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0466 - val_loss: 0.1623
# Epoch 25/200
# 13/13 [==============================] - 1s 104ms/step - loss: 0.0422 - val_loss: 0.3566
# Epoch 26/200
# 13/13 [==============================] - 1s 111ms/step - loss: 0.0375 - val_loss: 0.3094
# Epoch 27/200
# 13/13 [==============================] - 1s 113ms/step - loss: 0.0372 - val_loss: 0.2535
# Epoch 28/200
# 13/13 [==============================] - 1s 110ms/step - loss: 0.0353 - val_loss: 0.3307
# Epoch 29/200
# 13/13 [==============================] - 1s 115ms/step - loss: 0.0361 - val_loss: 0.2472
# Epoch 30/200
# 13/13 [==============================] - 2s 121ms/step - loss: 0.0360 - val_loss: 0.2100
# Epoch 31/200
# 13/13 [==============================] - 1s 115ms/step - loss: 0.0342 - val_loss: 0.3249
# Epoch 32/200
# 13/13 [==============================] - 2s 120ms/step - loss: 0.0336 - val_loss: 0.2823
# Epoch 33/200
# 13/13 [==============================] - 1s 113ms/step - loss: 0.0330 - val_loss: 0.1957
# Epoch 34/200
# 13/13 [==============================] - 1s 114ms/step - loss: 0.0354 - val_loss: 0.3733
# 8/8 [==============================] - 1s 22ms/step
# 2036.3349006962972
# Epoch 1/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 17
#      13 model.compile(optimizer='adam', loss="mean_squared_error")
#      15 callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
# ---> 17 model.fit(
#      18     x_train,
#      19     y_train,
#      20     validation_split=0.2,
#      21     epochs=200,
#      22     batch_size=64,
#      23     callbacks=callbacks,
#      24 )
#      25 predictions = model.predict(x_test)
#      26 predictions = output_scaler.inverse_transform(predictions)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\def_function.py:980, in Function._call(self, *args, **kwds)
#     976     pass  # Fall through to cond-based initialization.
#     977   else:
#     978     # Lifting succeeded, so variables are initialized and we can run the
#     979     # stateless function.
# --> 980     return self._stateless_fn(*args, **kwds)
#     981 else:
#     982   _, _, filtered_flat_args = (
#     983       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     984           *args, **kwds))
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\intern2\.conda\envs\machineLearnng\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
predictions = model.predict(x_test)
predictions = output_scaler.inverse_transform(predictions)
rmse = np.sqrt(np.mean(predictions - y_test)**2)
print(rmse)
# Out:
# 8/8 [==============================] - 1s 85ms/step
# 1624.7013374142532

# %%
train = np.squeeze(price_list[:training_data_len])
valid = np.squeeze(price_list[training_data_len:])
predictions = np.squeeze(predictions)
train_date_list = date_list[:training_data_len]
valid_date_list = date_list[training_data_len:]
valid_date_list2 = date_list[training_data_len:]
fig = go.Figure()
fig.add_trace(go.Scatter(x=train_date_list, y=train, name='train',  mode='lines'))
fig.add_trace(go.Scatter(x=valid_date_list, y=valid, name='valid',  mode='lines'))
fig.add_trace(go.Scatter(x=valid_date_list2, y=predictions, name='predict',  mode='lines'))
fig.show()
