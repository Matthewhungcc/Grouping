# %%
#https://keras.io/examples/timeseries/timeseries_transformer_classification/
#https://saturncloud.io/blog/understanding-keras-conv1d-layer-parameters-filters-and-kernel-size/#:~:text=Filters%20in%20Conv1D&text=In%20the%20context%20of%20Conv1D,pattern%20in%20the%20input%20data.
import math
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import plotly.graph_objects as go

df = pd.read_excel('Data.xlsx', sheet_name=6)
ordered_df = df.iloc[::-1]

date_list = df.iloc[:, 0].values
price_list = df.iloc[:, 1].values
features_list = df.iloc[:, 1:16].values

#Scale data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(features_list)
price_list = np.reshape(price_list, (price_list.shape[0], 1))
output_scaler = StandardScaler()
scaled_output_data = output_scaler.fit_transform(price_list)
print(scaled_output_data, scaled_data)
#Train test split
training_data_len = math.ceil(len(scaled_data)* .8)
training_data_len

#Train test split
train_data = scaled_data[0:training_data_len, :]
x_train = []
y_train = []
look_back_window = 12

for i in range(look_back_window, len(train_data)):
    x_train.append(train_data[i-look_back_window:i])
    y_train.append(train_data[i, 0])
#Convert to np array
x_train, y_train = np.array(x_train), np.array(y_train)

test_data = scaled_data[training_data_len-look_back_window:, :]

x_test = []
y_test = price_list[training_data_len:]
y_test = np.array(y_test)
y_test = np.reshape(y_test, (y_test.shape[0], 1))

for i in range(look_back_window, len(test_data)):
    x_test.append(test_data[i-look_back_window:i])

x_test = np.array(x_test)
# Out:
# [[-0.46940272]
#  [-0.52389849]
#  [-0.52127137]
#  ...
#  [ 2.37696601]
#  [ 2.40632341]
#  [ 2.39438903]] [[-0.46940272  0.13274505 -0.45581854 ... -1.12988853 -0.434165
#   -0.57681784]
#  [-0.52389849  0.2997445  -0.47795805 ... -1.09742737  0.66558632
#    0.09290279]
#  [-0.52127137  0.73211242 -0.51872857 ... -1.09670065  0.66643686
#    0.08928268]
#  ...
#  [ 2.37696601 -0.64178697  2.36635699 ...  3.62238733 -0.66976524
#   -0.59672845]
#  [ 2.40632341 -0.89322437  2.39136356 ...  2.4601506  -0.52687412
#   -0.56143236]
#  [ 2.39438903 -0.99259071  2.40209315 ...  2.3247775  -0.55834419
#   -0.56324242]]

# %%
from tensorflow import keras
from tensorflow.keras import layers
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

# %%
input_shape = x_train.shape[1:]

head_size_list = [64, 128, 512]
ff_dim_list = [2, 4, 8, 16]
mlp_units_list = [64, 128, 512]
mlp_dropout_list = [0.1, 0.2, 0.3]
dropout_list = [0.1, 0.2, 0.3]
result = []
for head_size in head_size_list:
    for ff_dim in ff_dim_list:
        for mlp_units in mlp_units_list:
            for mlp_dropout in mlp_dropout_list:
                for dropout in dropout_list:
                    model = build_model(
                        input_shape,
                        head_size=head_size,
                        num_heads=4,
                        ff_dim=ff_dim,
                        num_transformer_blocks=10,
                        mlp_units=[mlp_units],
                        mlp_dropout=mlp_dropout,
                        dropout=dropout,
                    )

                    model.compile(optimizer='adam', loss="mean_squared_error")

                    callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

                    model.fit(
                        x_train,
                        y_train,
                        validation_split=0.2,
                        epochs=200,
                        batch_size=64,
                        callbacks=callbacks,
                        verbose=0
                    )
                    predictions = model.predict(x_test)
                    predictions = output_scaler.inverse_transform(predictions)
                    rmse = np.sqrt(np.mean(predictions - y_test)**2)
                    print(head_size, ff_dim, mlp_units, mlp_dropout, dropout)
                    print(rmse)
                    result.append({"rmse":rmse, "head_size":head_size, "ff_dim":ff_dim, "mlp_units":mlp_units, "mlp_dropout":mlp_dropout, "dropout":dropout})
                    if  rmse < 100:
                        train = np.squeeze(price_list[:training_data_len])
                        valid = np.squeeze(price_list[training_data_len:])
                        predictions = np.squeeze(predictions)
                        train_date_list = date_list[:training_data_len]
                        valid_date_list = date_list[training_data_len:]
                        valid_date_list2 = date_list[training_data_len:]
                        fig = go.Figure()
                        fig.add_trace(go.Scatter(x=train_date_list, y=train, name='train',  mode='lines'))
                        fig.add_trace(go.Scatter(x=valid_date_list, y=valid, name='valid',  mode='lines'))
                        fig.add_trace(go.Scatter(x=valid_date_list2, y=predictions, name='predict',  mode='lines'))
                        fig.show()

# %%
input_shape = x_train.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=8,
    mlp_units=[128],
    mlp_dropout=0.25,
    dropout=0.25,
)
model.summary()
model.compile(optimizer='adam', loss="mean_squared_error")

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

model.fit(
    x_train,
    y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=64,
    callbacks=callbacks,
)
predictions = model.predict(x_test)
predictions = output_scaler.inverse_transform(predictions)
rmse = np.sqrt(np.mean(predictions - y_test)**2)
print(rmse)
# Out:
# Model: "model_291"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_292 (InputLayer)         [(None, 14, 14)]     0           []
#
#  layer_normalization_5824 (Laye  (None, 14, 14)      28          ['input_292[0][0]']
#  rNormalization)
#
#  multi_head_attention_2912 (Mul  (None, 14, 14)      60430       ['layer_normalization_5824[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5824[0][0]
#                                                                  ']
#
#  dropout_6115 (Dropout)         (None, 14, 14)       0           ['multi_head_attention_2912[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5824 (TFO  (None, 14, 14)      0           ['dropout_6115[0][0]',
#  pLambda)                                                         'input_292[0][0]']
#
#  layer_normalization_5825 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5824[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5824 (Conv1D)           (None, 14, 4)        60          ['layer_normalization_5825[0][0]'
#                                                                  ]
#
#  dropout_6116 (Dropout)         (None, 14, 4)        0           ['conv1d_5824[0][0]']
#
#  conv1d_5825 (Conv1D)           (None, 14, 14)       70          ['dropout_6116[0][0]']
#
#  tf.__operators__.add_5825 (TFO  (None, 14, 14)      0           ['conv1d_5825[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5824[0][0]
#                                                                  ']
#
#  layer_normalization_5826 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5825[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2913 (Mul  (None, 14, 14)      60430       ['layer_normalization_5826[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5826[0][0]
#                                                                  ']
#
#  dropout_6117 (Dropout)         (None, 14, 14)       0           ['multi_head_attention_2913[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5826 (TFO  (None, 14, 14)      0           ['dropout_6117[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5825[0][0]
#                                                                  ']
#
#  layer_normalization_5827 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5826[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5826 (Conv1D)           (None, 14, 4)        60          ['layer_normalization_5827[0][0]'
#                                                                  ]
#
#  dropout_6118 (Dropout)         (None, 14, 4)        0           ['conv1d_5826[0][0]']
#
#  conv1d_5827 (Conv1D)           (None, 14, 14)       70          ['dropout_6118[0][0]']
#
#  tf.__operators__.add_5827 (TFO  (None, 14, 14)      0           ['conv1d_5827[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5826[0][0]
#                                                                  ']
#
#  layer_normalization_5828 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5827[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2914 (Mul  (None, 14, 14)      60430       ['layer_normalization_5828[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5828[0][0]
#                                                                  ']
#
#  dropout_6119 (Dropout)         (None, 14, 14)       0           ['multi_head_attention_2914[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5828 (TFO  (None, 14, 14)      0           ['dropout_6119[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5827[0][0]
#                                                                  ']
#
#  layer_normalization_5829 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5828[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5828 (Conv1D)           (None, 14, 4)        60          ['layer_normalization_5829[0][0]'
#                                                                  ]
#
#  dropout_6120 (Dropout)         (None, 14, 4)        0           ['conv1d_5828[0][0]']
#
#  conv1d_5829 (Conv1D)           (None, 14, 14)       70          ['dropout_6120[0][0]']
#
#  tf.__operators__.add_5829 (TFO  (None, 14, 14)      0           ['conv1d_5829[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5828[0][0]
#                                                                  ']
#
#  layer_normalization_5830 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5829[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2915 (Mul  (None, 14, 14)      60430       ['layer_normalization_5830[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5830[0][0]
#                                                                  ']
#
#  dropout_6121 (Dropout)         (None, 14, 14)       0           ['multi_head_attention_2915[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5830 (TFO  (None, 14, 14)      0           ['dropout_6121[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5829[0][0]
#                                                                  ']
#
#  layer_normalization_5831 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5830[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5830 (Conv1D)           (None, 14, 4)        60          ['layer_normalization_5831[0][0]'
#                                                                  ]
#
#  dropout_6122 (Dropout)         (None, 14, 4)        0           ['conv1d_5830[0][0]']
#
#  conv1d_5831 (Conv1D)           (None, 14, 14)       70          ['dropout_6122[0][0]']
#
#  tf.__operators__.add_5831 (TFO  (None, 14, 14)      0           ['conv1d_5831[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5830[0][0]
#                                                                  ']
#
#  layer_normalization_5832 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5831[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2916 (Mul  (None, 14, 14)      60430       ['layer_normalization_5832[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5832[0][0]
#                                                                  ']
#
#  dropout_6123 (Dropout)         (None, 14, 14)       0           ['multi_head_attention_2916[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5832 (TFO  (None, 14, 14)      0           ['dropout_6123[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5831[0][0]
#                                                                  ']
#
#  layer_normalization_5833 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5832[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5832 (Conv1D)           (None, 14, 4)        60          ['layer_normalization_5833[0][0]'
#                                                                  ]
#
#  dropout_6124 (Dropout)         (None, 14, 4)        0           ['conv1d_5832[0][0]']
#
#  conv1d_5833 (Conv1D)           (None, 14, 14)       70          ['dropout_6124[0][0]']
#
#  tf.__operators__.add_5833 (TFO  (None, 14, 14)      0           ['conv1d_5833[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5832[0][0]
#                                                                  ']
#
#  layer_normalization_5834 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5833[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2917 (Mul  (None, 14, 14)      60430       ['layer_normalization_5834[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5834[0][0]
#                                                                  ']
#
#  dropout_6125 (Dropout)         (None, 14, 14)       0           ['multi_head_attention_2917[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5834 (TFO  (None, 14, 14)      0           ['dropout_6125[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5833[0][0]
#                                                                  ']
#
#  layer_normalization_5835 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5834[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5834 (Conv1D)           (None, 14, 4)        60          ['layer_normalization_5835[0][0]'
#                                                                  ]
#
#  dropout_6126 (Dropout)         (None, 14, 4)        0           ['conv1d_5834[0][0]']
#
#  conv1d_5835 (Conv1D)           (None, 14, 14)       70          ['dropout_6126[0][0]']
#
#  tf.__operators__.add_5835 (TFO  (None, 14, 14)      0           ['conv1d_5835[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5834[0][0]
#                                                                  ']
#
#  layer_normalization_5836 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5835[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2918 (Mul  (None, 14, 14)      60430       ['layer_normalization_5836[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5836[0][0]
#                                                                  ']
#
#  dropout_6127 (Dropout)         (None, 14, 14)       0           ['multi_head_attention_2918[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5836 (TFO  (None, 14, 14)      0           ['dropout_6127[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5835[0][0]
#                                                                  ']
#
#  layer_normalization_5837 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5836[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5836 (Conv1D)           (None, 14, 4)        60          ['layer_normalization_5837[0][0]'
#                                                                  ]
#
#  dropout_6128 (Dropout)         (None, 14, 4)        0           ['conv1d_5836[0][0]']
#
#  conv1d_5837 (Conv1D)           (None, 14, 14)       70          ['dropout_6128[0][0]']
#
#  tf.__operators__.add_5837 (TFO  (None, 14, 14)      0           ['conv1d_5837[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5836[0][0]
#                                                                  ']
#
#  layer_normalization_5838 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5837[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2919 (Mul  (None, 14, 14)      60430       ['layer_normalization_5838[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5838[0][0]
#                                                                  ']
#
#  dropout_6129 (Dropout)         (None, 14, 14)       0           ['multi_head_attention_2919[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5838 (TFO  (None, 14, 14)      0           ['dropout_6129[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5837[0][0]
#                                                                  ']
#
#  layer_normalization_5839 (Laye  (None, 14, 14)      28          ['tf.__operators__.add_5838[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5838 (Conv1D)           (None, 14, 4)        60          ['layer_normalization_5839[0][0]'
#                                                                  ]
#
#  dropout_6130 (Dropout)         (None, 14, 4)        0           ['conv1d_5838[0][0]']
#
#  conv1d_5839 (Conv1D)           (None, 14, 14)       70          ['dropout_6130[0][0]']
#
#  tf.__operators__.add_5839 (TFO  (None, 14, 14)      0           ['conv1d_5839[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5838[0][0]
#                                                                  ']
#
#  global_average_pooling1d_291 (  (None, 14)          0           ['tf.__operators__.add_5839[0][0]
#  GlobalAveragePooling1D)                                         ']
#
#  dense_582 (Dense)              (None, 128)          1920        ['global_average_pooling1d_291[0]
#                                                                  [0]']
#
#  dropout_6131 (Dropout)         (None, 128)          0           ['dense_582[0][0]']
#
#  dense_583 (Dense)              (None, 1)            129         ['dropout_6131[0][0]']
#
# ==================================================================================================
# Total params: 486,977
# Trainable params: 486,977
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/200
# 13/13 [==============================] - 19s 743ms/step - loss: 0.1479 - val_loss: 0.0545
# Epoch 2/200
# 13/13 [==============================] - 8s 646ms/step - loss: 0.0602 - val_loss: 0.1162
# Epoch 3/200
# 13/13 [==============================] - 8s 641ms/step - loss: 0.0383 - val_loss: 0.0467
# Epoch 4/200
# 13/13 [==============================] - 8s 632ms/step - loss: 0.0281 - val_loss: 0.0532
# Epoch 5/200
# 13/13 [==============================] - 8s 638ms/step - loss: 0.0255 - val_loss: 0.0367
# Epoch 6/200
# 13/13 [==============================] - 8s 633ms/step - loss: 0.0271 - val_loss: 0.0049
# Epoch 7/200
# 13/13 [==============================] - 8s 632ms/step - loss: 0.0235 - val_loss: 0.0066
# Epoch 8/200
# 13/13 [==============================] - 8s 629ms/step - loss: 0.0355 - val_loss: 0.0084
# Epoch 9/200
# 13/13 [==============================] - 8s 631ms/step - loss: 0.0290 - val_loss: 0.0691
# Epoch 10/200
# 13/13 [==============================] - 8s 639ms/step - loss: 0.0199 - val_loss: 0.0320
# Epoch 11/200
# 13/13 [==============================] - 8s 642ms/step - loss: 0.0158 - val_loss: 0.0071
# Epoch 12/200
# 13/13 [==============================] - 8s 648ms/step - loss: 0.0146 - val_loss: 0.0040
# Epoch 13/200
# 13/13 [==============================] - 8s 634ms/step - loss: 0.0132 - val_loss: 0.0039
# Epoch 14/200
# 13/13 [==============================] - 8s 632ms/step - loss: 0.0127 - val_loss: 0.0088
# Epoch 15/200
# 13/13 [==============================] - 8s 637ms/step - loss: 0.0125 - val_loss: 0.0112
# Epoch 16/200
# 13/13 [==============================] - 9s 661ms/step - loss: 0.0111 - val_loss: 0.0085
# Epoch 17/200
# 13/13 [==============================] - 9s 668ms/step - loss: 0.0121 - val_loss: 0.0148
# Epoch 18/200
# 13/13 [==============================] - 9s 682ms/step - loss: 0.0126 - val_loss: 0.0194
# Epoch 19/200
# 13/13 [==============================] - 9s 663ms/step - loss: 0.0110 - val_loss: 0.0173
# Epoch 20/200
# 13/13 [==============================] - 9s 683ms/step - loss: 0.0116 - val_loss: 0.0041
# Epoch 21/200
# 13/13 [==============================] - 8s 637ms/step - loss: 0.0102 - val_loss: 0.0049
# Epoch 22/200
# 13/13 [==============================] - 8s 644ms/step - loss: 0.0100 - val_loss: 0.0197
# Epoch 23/200
# 13/13 [==============================] - 8s 647ms/step - loss: 0.0098 - val_loss: 0.0051
# 8/8 [==============================] - 2s 157ms/step
# 28.96345651518039

# %%
predictions = model.predict(x_test)
predictions = output_scaler.inverse_transform(predictions)
rmse = np.sqrt(np.mean(predictions - y_test)**2)
print(rmse)
# Out:
# 8/8 [==============================] - 1s 151ms/step
# 28.96345651518039

# %%
train = np.squeeze(price_list[:training_data_len])
valid = np.squeeze(price_list[training_data_len:])
predictions = np.squeeze(predictions)
train_date_list = date_list[:training_data_len]
valid_date_list = date_list[training_data_len:]
valid_date_list2 = date_list[training_data_len:]
fig = go.Figure()
fig.add_trace(go.Scatter(x=train_date_list, y=train, name='train',  mode='lines'))
fig.add_trace(go.Scatter(x=valid_date_list, y=valid, name='valid',  mode='lines'))
fig.add_trace(go.Scatter(x=valid_date_list2, y=predictions, name='predict',  mode='lines'))
fig.show()

# %%
input_shape = x_train.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=8,
    num_transformer_blocks=10,
    mlp_units=[128],
    mlp_dropout=0.2,
    dropout=0.2,
)
model.summary()
model.compile(optimizer='adam', loss="mean_squared_error")

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

model.fit(
    x_train,
    y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=32,
    callbacks=callbacks,
    shuffle=True
)
predictions = model.predict(x_test)
predictions = output_scaler.inverse_transform(predictions)
rmse = np.sqrt(np.mean(predictions - y_test)**2)
print(rmse)
# Out:
# Model: "model_299"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_303 (InputLayer)         [(None, 12, 13)]     0           []
#
#  layer_normalization_5960 (Laye  (None, 12, 13)      26          ['input_303[0][0]']
#  rNormalization)
#
#  multi_head_attention_2980 (Mul  (None, 12, 13)      56333       ['layer_normalization_5960[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5960[0][0]
#                                                                  ']
#
#  dropout_6259 (Dropout)         (None, 12, 13)       0           ['multi_head_attention_2980[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5960 (TFO  (None, 12, 13)      0           ['dropout_6259[0][0]',
#  pLambda)                                                         'input_303[0][0]']
#
#  layer_normalization_5961 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5960[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5960 (Conv1D)           (None, 12, 8)        112         ['layer_normalization_5961[0][0]'
#                                                                  ]
#
#  dropout_6260 (Dropout)         (None, 12, 8)        0           ['conv1d_5960[0][0]']
#
#  conv1d_5961 (Conv1D)           (None, 12, 13)       117         ['dropout_6260[0][0]']
#
#  tf.__operators__.add_5961 (TFO  (None, 12, 13)      0           ['conv1d_5961[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5960[0][0]
#                                                                  ']
#
#  layer_normalization_5962 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5961[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2981 (Mul  (None, 12, 13)      56333       ['layer_normalization_5962[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5962[0][0]
#                                                                  ']
#
#  dropout_6261 (Dropout)         (None, 12, 13)       0           ['multi_head_attention_2981[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5962 (TFO  (None, 12, 13)      0           ['dropout_6261[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5961[0][0]
#                                                                  ']
#
#  layer_normalization_5963 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5962[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5962 (Conv1D)           (None, 12, 8)        112         ['layer_normalization_5963[0][0]'
#                                                                  ]
#
#  dropout_6262 (Dropout)         (None, 12, 8)        0           ['conv1d_5962[0][0]']
#
#  conv1d_5963 (Conv1D)           (None, 12, 13)       117         ['dropout_6262[0][0]']
#
#  tf.__operators__.add_5963 (TFO  (None, 12, 13)      0           ['conv1d_5963[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5962[0][0]
#                                                                  ']
#
#  layer_normalization_5964 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5963[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2982 (Mul  (None, 12, 13)      56333       ['layer_normalization_5964[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5964[0][0]
#                                                                  ']
#
#  dropout_6263 (Dropout)         (None, 12, 13)       0           ['multi_head_attention_2982[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5964 (TFO  (None, 12, 13)      0           ['dropout_6263[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5963[0][0]
#                                                                  ']
#
#  layer_normalization_5965 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5964[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5964 (Conv1D)           (None, 12, 8)        112         ['layer_normalization_5965[0][0]'
#                                                                  ]
#
#  dropout_6264 (Dropout)         (None, 12, 8)        0           ['conv1d_5964[0][0]']
#
#  conv1d_5965 (Conv1D)           (None, 12, 13)       117         ['dropout_6264[0][0]']
#
#  tf.__operators__.add_5965 (TFO  (None, 12, 13)      0           ['conv1d_5965[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5964[0][0]
#                                                                  ']
#
#  layer_normalization_5966 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5965[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2983 (Mul  (None, 12, 13)      56333       ['layer_normalization_5966[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5966[0][0]
#                                                                  ']
#
#  dropout_6265 (Dropout)         (None, 12, 13)       0           ['multi_head_attention_2983[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5966 (TFO  (None, 12, 13)      0           ['dropout_6265[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5965[0][0]
#                                                                  ']
#
#  layer_normalization_5967 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5966[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5966 (Conv1D)           (None, 12, 8)        112         ['layer_normalization_5967[0][0]'
#                                                                  ]
#
#  dropout_6266 (Dropout)         (None, 12, 8)        0           ['conv1d_5966[0][0]']
#
#  conv1d_5967 (Conv1D)           (None, 12, 13)       117         ['dropout_6266[0][0]']
#
#  tf.__operators__.add_5967 (TFO  (None, 12, 13)      0           ['conv1d_5967[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5966[0][0]
#                                                                  ']
#
#  layer_normalization_5968 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5967[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2984 (Mul  (None, 12, 13)      56333       ['layer_normalization_5968[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5968[0][0]
#                                                                  ']
#
#  dropout_6267 (Dropout)         (None, 12, 13)       0           ['multi_head_attention_2984[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5968 (TFO  (None, 12, 13)      0           ['dropout_6267[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5967[0][0]
#                                                                  ']
#
#  layer_normalization_5969 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5968[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5968 (Conv1D)           (None, 12, 8)        112         ['layer_normalization_5969[0][0]'
#                                                                  ]
#
#  dropout_6268 (Dropout)         (None, 12, 8)        0           ['conv1d_5968[0][0]']
#
#  conv1d_5969 (Conv1D)           (None, 12, 13)       117         ['dropout_6268[0][0]']
#
#  tf.__operators__.add_5969 (TFO  (None, 12, 13)      0           ['conv1d_5969[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5968[0][0]
#                                                                  ']
#
#  layer_normalization_5970 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5969[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2985 (Mul  (None, 12, 13)      56333       ['layer_normalization_5970[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5970[0][0]
#                                                                  ']
#
#  dropout_6269 (Dropout)         (None, 12, 13)       0           ['multi_head_attention_2985[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5970 (TFO  (None, 12, 13)      0           ['dropout_6269[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5969[0][0]
#                                                                  ']
#
#  layer_normalization_5971 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5970[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5970 (Conv1D)           (None, 12, 8)        112         ['layer_normalization_5971[0][0]'
#                                                                  ]
#
#  dropout_6270 (Dropout)         (None, 12, 8)        0           ['conv1d_5970[0][0]']
#
#  conv1d_5971 (Conv1D)           (None, 12, 13)       117         ['dropout_6270[0][0]']
#
#  tf.__operators__.add_5971 (TFO  (None, 12, 13)      0           ['conv1d_5971[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5970[0][0]
#                                                                  ']
#
#  layer_normalization_5972 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5971[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2986 (Mul  (None, 12, 13)      56333       ['layer_normalization_5972[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5972[0][0]
#                                                                  ']
#
#  dropout_6271 (Dropout)         (None, 12, 13)       0           ['multi_head_attention_2986[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5972 (TFO  (None, 12, 13)      0           ['dropout_6271[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5971[0][0]
#                                                                  ']
#
#  layer_normalization_5973 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5972[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5972 (Conv1D)           (None, 12, 8)        112         ['layer_normalization_5973[0][0]'
#                                                                  ]
#
#  dropout_6272 (Dropout)         (None, 12, 8)        0           ['conv1d_5972[0][0]']
#
#  conv1d_5973 (Conv1D)           (None, 12, 13)       117         ['dropout_6272[0][0]']
#
#  tf.__operators__.add_5973 (TFO  (None, 12, 13)      0           ['conv1d_5973[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5972[0][0]
#                                                                  ']
#
#  layer_normalization_5974 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5973[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2987 (Mul  (None, 12, 13)      56333       ['layer_normalization_5974[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5974[0][0]
#                                                                  ']
#
#  dropout_6273 (Dropout)         (None, 12, 13)       0           ['multi_head_attention_2987[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5974 (TFO  (None, 12, 13)      0           ['dropout_6273[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5973[0][0]
#                                                                  ']
#
#  layer_normalization_5975 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5974[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5974 (Conv1D)           (None, 12, 8)        112         ['layer_normalization_5975[0][0]'
#                                                                  ]
#
#  dropout_6274 (Dropout)         (None, 12, 8)        0           ['conv1d_5974[0][0]']
#
#  conv1d_5975 (Conv1D)           (None, 12, 13)       117         ['dropout_6274[0][0]']
#
#  tf.__operators__.add_5975 (TFO  (None, 12, 13)      0           ['conv1d_5975[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5974[0][0]
#                                                                  ']
#
#  layer_normalization_5976 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5975[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2988 (Mul  (None, 12, 13)      56333       ['layer_normalization_5976[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5976[0][0]
#                                                                  ']
#
#  dropout_6275 (Dropout)         (None, 12, 13)       0           ['multi_head_attention_2988[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5976 (TFO  (None, 12, 13)      0           ['dropout_6275[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5975[0][0]
#                                                                  ']
#
#  layer_normalization_5977 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5976[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5976 (Conv1D)           (None, 12, 8)        112         ['layer_normalization_5977[0][0]'
#                                                                  ]
#
#  dropout_6276 (Dropout)         (None, 12, 8)        0           ['conv1d_5976[0][0]']
#
#  conv1d_5977 (Conv1D)           (None, 12, 13)       117         ['dropout_6276[0][0]']
#
#  tf.__operators__.add_5977 (TFO  (None, 12, 13)      0           ['conv1d_5977[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5976[0][0]
#                                                                  ']
#
#  layer_normalization_5978 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5977[0][0]
#  rNormalization)                                                 ']
#
#  multi_head_attention_2989 (Mul  (None, 12, 13)      56333       ['layer_normalization_5978[0][0]'
#  tiHeadAttention)                                                , 'layer_normalization_5978[0][0]
#                                                                  ']
#
#  dropout_6277 (Dropout)         (None, 12, 13)       0           ['multi_head_attention_2989[0][0]
#                                                                  ']
#
#  tf.__operators__.add_5978 (TFO  (None, 12, 13)      0           ['dropout_6277[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5977[0][0]
#                                                                  ']
#
#  layer_normalization_5979 (Laye  (None, 12, 13)      26          ['tf.__operators__.add_5978[0][0]
#  rNormalization)                                                 ']
#
#  conv1d_5978 (Conv1D)           (None, 12, 8)        112         ['layer_normalization_5979[0][0]'
#                                                                  ]
#
#  dropout_6278 (Dropout)         (None, 12, 8)        0           ['conv1d_5978[0][0]']
#
#  conv1d_5979 (Conv1D)           (None, 12, 13)       117         ['dropout_6278[0][0]']
#
#  tf.__operators__.add_5979 (TFO  (None, 12, 13)      0           ['conv1d_5979[0][0]',
#  pLambda)                                                         'tf.__operators__.add_5978[0][0]
#                                                                  ']
#
#  global_average_pooling1d_299 (  (None, 12)          0           ['tf.__operators__.add_5979[0][0]
#  GlobalAveragePooling1D)                                         ']
#
#  dense_598 (Dense)              (None, 128)          1664        ['global_average_pooling1d_299[0]
#                                                                  [0]']
#
#  dropout_6279 (Dropout)         (None, 128)          0           ['dense_598[0][0]']
#
#  dense_599 (Dense)              (None, 1)            129         ['dropout_6279[0][0]']
#
# ==================================================================================================
# Total params: 567,933
# Trainable params: 567,933
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/200
# 124/124 [==============================] - 72s 485ms/step - loss: 0.1058 - val_loss: 0.6021
# Epoch 2/200
# 124/124 [==============================] - 57s 461ms/step - loss: 0.0530 - val_loss: 0.4540
# Epoch 3/200
# 124/124 [==============================] - 56s 454ms/step - loss: 0.0423 - val_loss: 0.7536
# Epoch 4/200
# 124/124 [==============================] - 56s 455ms/step - loss: 0.0380 - val_loss: 0.1093
# Epoch 5/200
# 124/124 [==============================] - 57s 457ms/step - loss: 0.0136 - val_loss: 0.0553
# Epoch 6/200
# 124/124 [==============================] - 58s 465ms/step - loss: 0.0119 - val_loss: 0.0458
# Epoch 7/200
# 124/124 [==============================] - 58s 468ms/step - loss: 0.0089 - val_loss: 0.0364
# Epoch 8/200
# 124/124 [==============================] - 57s 459ms/step - loss: 0.0075 - val_loss: 0.0769
# Epoch 9/200
# 124/124 [==============================] - 61s 489ms/step - loss: 0.0065 - val_loss: 0.0312
# Epoch 10/200
# 124/124 [==============================] - 60s 486ms/step - loss: 0.0060 - val_loss: 0.0275
# Epoch 11/200
# 124/124 [==============================] - 60s 487ms/step - loss: 0.0059 - val_loss: 0.0201
# Epoch 12/200
# 124/124 [==============================] - 59s 478ms/step - loss: 0.0056 - val_loss: 0.0194
# Epoch 13/200
# 124/124 [==============================] - 59s 475ms/step - loss: 0.0047 - val_loss: 0.0159
# Epoch 14/200
# 124/124 [==============================] - 59s 474ms/step - loss: 0.0047 - val_loss: 0.0279
# Epoch 15/200
# 124/124 [==============================] - 58s 468ms/step - loss: 0.0040 - val_loss: 0.0083
# Epoch 16/200
# 124/124 [==============================] - 59s 474ms/step - loss: 0.0042 - val_loss: 0.0110
# Epoch 17/200
# 124/124 [==============================] - 58s 470ms/step - loss: 0.0035 - val_loss: 0.0136
# Epoch 18/200
# 124/124 [==============================] - 58s 466ms/step - loss: 0.0032 - val_loss: 0.0276
# Epoch 19/200
# 124/124 [==============================] - 58s 468ms/step - loss: 0.0037 - val_loss: 0.0186
# Epoch 20/200
# 124/124 [==============================] - 58s 470ms/step - loss: 0.0035 - val_loss: 0.0234
# Epoch 21/200
# 124/124 [==============================] - 58s 468ms/step - loss: 0.0030 - val_loss: 0.0103
# Epoch 22/200
# 124/124 [==============================] - 58s 465ms/step - loss: 0.0032 - val_loss: 0.0253
# Epoch 23/200
# 124/124 [==============================] - 58s 471ms/step - loss: 0.0027 - val_loss: 0.0122
# Epoch 24/200
# 124/124 [==============================] - 59s 474ms/step - loss: 0.0029 - val_loss: 0.0160
# Epoch 25/200
# 124/124 [==============================] - 63s 507ms/step - loss: 0.0026 - val_loss: 0.0064
# Epoch 26/200
# 124/124 [==============================] - 61s 494ms/step - loss: 0.0026 - val_loss: 0.0137
# Epoch 27/200
# 124/124 [==============================] - 63s 505ms/step - loss: 0.0026 - val_loss: 0.0110
# Epoch 28/200
# 124/124 [==============================] - 64s 516ms/step - loss: 0.0025 - val_loss: 0.0114
# Epoch 29/200
# 124/124 [==============================] - 62s 504ms/step - loss: 0.0026 - val_loss: 0.0083
# Epoch 30/200
# 124/124 [==============================] - 63s 507ms/step - loss: 0.0024 - val_loss: 0.0060
# Epoch 31/200
# 124/124 [==============================] - 61s 494ms/step - loss: 0.0025 - val_loss: 0.0077
# Epoch 32/200
# 124/124 [==============================] - 58s 470ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 33/200
# 124/124 [==============================] - 60s 484ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 34/200
# 124/124 [==============================] - 62s 500ms/step - loss: 0.0023 - val_loss: 0.0151
# Epoch 35/200
# 124/124 [==============================] - 62s 504ms/step - loss: 0.0024 - val_loss: 0.0060
# Epoch 36/200
# 124/124 [==============================] - 64s 513ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 37/200
# 124/124 [==============================] - 64s 517ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 38/200
# 124/124 [==============================] - 61s 491ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 39/200
# 124/124 [==============================] - 60s 481ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 40/200
# 124/124 [==============================] - 61s 494ms/step - loss: 0.0029 - val_loss: 0.0098
# Epoch 41/200
# 124/124 [==============================] - 59s 473ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 42/200
# 124/124 [==============================] - 58s 470ms/step - loss: 0.0018 - val_loss: 0.0133
# Epoch 43/200
# 124/124 [==============================] - 58s 468ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 44/200
# 124/124 [==============================] - 58s 465ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 45/200
# 124/124 [==============================] - 59s 477ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 46/200
# 124/124 [==============================] - 60s 486ms/step - loss: 0.0018 - val_loss: 0.0193
# Epoch 47/200
# 124/124 [==============================] - 61s 493ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 48/200
# 124/124 [==============================] - 58s 471ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 49/200
# 124/124 [==============================] - 60s 484ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 50/200
# 124/124 [==============================] - 58s 469ms/step - loss: 0.0017 - val_loss: 0.0052
# Epoch 51/200
# 124/124 [==============================] - 58s 465ms/step - loss: 0.0019 - val_loss: 0.0037
# Epoch 52/200
# 124/124 [==============================] - 58s 465ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 53/200
# 124/124 [==============================] - 58s 469ms/step - loss: 0.0023 - val_loss: 0.0049
# Epoch 54/200
# 124/124 [==============================] - 58s 468ms/step - loss: 0.0016 - val_loss: 0.0034
# 39/39 [==============================] - 8s 177ms/step
# 72.86451006342509

# %%
train = np.squeeze(price_list[:training_data_len])
valid = np.squeeze(price_list[training_data_len:])
predictions = np.squeeze(predictions)
train_date_list = date_list[:training_data_len]
valid_date_list = date_list[training_data_len:]
valid_date_list2 = date_list[training_data_len:]
fig = go.Figure()
fig.add_trace(go.Scatter(x=train_date_list, y=train, name='train',  mode='lines'))
fig.add_trace(go.Scatter(x=valid_date_list, y=valid, name='valid',  mode='lines'))
fig.add_trace(go.Scatter(x=valid_date_list2, y=predictions, name='predict',  mode='lines'))
fig.show()
